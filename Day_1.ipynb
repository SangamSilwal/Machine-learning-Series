# %% [markdown]
# <a href="https://colab.research.google.com/github/SangamSilwal/Machine-learning-Series/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Handling CSV File**

# %%
df = pd.read_csv("/content/netflix_titles.csv")
# for handling the tsv (tab seperated value we will use sep="\t")

# %%
pd.read_csv("/content/netflix_titles.csv",index_col="show_id")
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
pd.read_csv("/content/netflix_titles.csv",header=1)  #This will set the header to the 1 st row
# Out:
#          s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 0        s2  TV Show          Blood & Water              NaN
# 1        s3  TV Show              Ganglands  Julien Leclercq
# 2        s4  TV Show  Jailbirds New Orleans              NaN
# 3        s5  TV Show           Kota Factory              NaN
# 4        s6  TV Show          Midnight Mass    Mike Flanagan
# ...     ...      ...                    ...              ...
# 8801  s8803    Movie                 Zodiac    David Fincher
# 8802  s8804  TV Show            Zombie Dumb              NaN
# 8803  s8805    Movie             Zombieland  Ruben Fleischer
# 8804  s8806    Movie                   Zoom     Peter Hewitt
# 8805  s8807    Movie                 Zubaan      Mozez Singh
#
#                                              Unnamed: 4  United States  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %% [markdown]
# Squeeze Parameters

# %%
newDF = pd.read_csv("/content/netflix_titles.csv",usecols=["type"])
newDF["type"] #Converting into Series
# squeeze=true is depreciated
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %% [markdown]
# Skip rows / nrows

# %%
pd.read_csv("/content/netflix_titles.csv",skiprows=[1,2,3])
# Out:
#      show_id     type                             title  \
# 0         s4  TV Show             Jailbirds New Orleans
# 1         s5  TV Show                      Kota Factory
# 2         s6  TV Show                     Midnight Mass
# 3         s7    Movie  My Little Pony: A New Generation
# 4         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8799   s8803    Movie                            Zodiac
# 8800   s8804  TV Show                       Zombie Dumb
# 8801   s8805    Movie                        Zombieland
# 8802   s8806    Movie                              Zoom
# 8803   s8807    Movie                            Zubaan
#
#                            director  \
# 0                               NaN
# 1                               NaN
# 2                     Mike Flanagan
# 3     Robert Cullen, José Luis Ucha
# 4                      Haile Gerima
# ...                             ...
# ...

# %%
pd.read_csv("/content/netflix_titles.csv",nrows=20)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
# skip bad lines

# %%
# For skipping the bad lines we can normally use error_bad_lines=False

# %%
# Handling Dates Data in Pandas
new_data = pd.read_csv("/content/netflix_titles.csv",parse_dates=['date_added','release_year'])
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   datetime64[ns]
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 825.8+ KB

# %%
# Using Converters in Pandas
def rename(type):
  if type == "TV Show":
    return "TVS"
  else:
    return 'MV'
pd.read_csv("/content/netflix_titles.csv",converters={'type':rename})
# Out:
#      show_id type                  title         director  \
# 0         s1   MV   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TVS          Blood & Water              NaN
# 2         s3  TVS              Ganglands  Julien Leclercq
# 3         s4  TVS  Jailbirds New Orleans              NaN
# 4         s5  TVS           Kota Factory              NaN
# ...      ...  ...                    ...              ...
# 8802   s8803   MV                 Zodiac    David Fincher
# 8803   s8804  TVS            Zombie Dumb              NaN
# 8804   s8805   MV             Zombieland  Ruben Fleischer
# 8805   s8806   MV                   Zoom     Peter Hewitt
# 8806   s8807   MV                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# na_values parameter

# %%
pd.read_csv("/content/netflix_titles.csv",na_values=["Movie"])
# Out:
#      show_id     type                  title         director  \
# 0         s1      NaN   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803      NaN                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805      NaN             Zombieland  Ruben Fleischer
# 8805   s8806      NaN                   Zoom     Peter Hewitt
# 8806   s8807      NaN                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Loading a huge dataset in Chunks
dfs = pd.read_csv("/content/netflix_titles.csv",chunksize=2000)

# %%
for chunk in dfs:
  print(chunk.shape)
# Out:
# (2000, 12)
# (2000, 12)
# (2000, 12)
# (807, 12)
