# %% [markdown]
# <a href="https://colab.research.google.com/github/SangamSilwal/Machine-learning-Series/blob/main/Bagging_VS_RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5, n_informative=5, n_redundant=0, random_state=0, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target']=y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -2.688014  2.517617 -3.709784  0.497767  2.006716       0
# 1 -0.897058  1.000720 -1.262075  0.503085  1.614389       0
# 2  0.454782 -2.461140 -1.100978 -1.861955 -2.480726       1
# 3  0.302512 -0.595175  0.834284  3.635996  0.542202       1
# 4 -0.578231  0.554277 -0.264237  1.170973  0.743356       0

# %%
bag = BaggingClassifier(max_features=3)
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=3)

# %%
bag.estimators_
# Out:
# [DecisionTreeClassifier(random_state=1418221638),
#  DecisionTreeClassifier(random_state=1594197119),
#  DecisionTreeClassifier(random_state=274855637),
#  DecisionTreeClassifier(random_state=1985842461),
#  DecisionTreeClassifier(random_state=110052443),
#  DecisionTreeClassifier(random_state=1698238337),
#  DecisionTreeClassifier(random_state=1836111654),
#  DecisionTreeClassifier(random_state=944616890),
#  DecisionTreeClassifier(random_state=433460108),
#  DecisionTreeClassifier(random_state=246054591)]

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features=2, random_state=720711314),
#  DecisionTreeClassifier(max_features=2, random_state=1724323168),
#  DecisionTreeClassifier(max_features=2, random_state=529306686),
#  DecisionTreeClassifier(max_features=2, random_state=1962160239),
#  DecisionTreeClassifier(max_features=2, random_state=820886519),
#  DecisionTreeClassifier(max_features=2, random_state=1841141171),
#  DecisionTreeClassifier(max_features=2, random_state=1480313814),
#  DecisionTreeClassifier(max_features=2, random_state=1496903015),
#  DecisionTreeClassifier(max_features=2, random_state=1044974963),
#  DecisionTreeClassifier(max_features=2, random_state=202553687),
#  DecisionTreeClassifier(max_features=2, random_state=1539460627),
#  DecisionTreeClassifier(max_features=2, random_state=1529163905),
#  DecisionTreeClassifier(max_features=2, random_state=1614082135),
#  DecisionTreeClassifier(max_features=2, random_state=1531643920),
# ...

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
