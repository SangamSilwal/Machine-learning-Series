# %% [markdown]
# <a href="https://colab.research.google.com/github/SangamSilwal/Machine-learning-Series/blob/main/Day_6_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handling Data and time

# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv("orders.csv")
time = pd.read_csv("messages.csv")

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# # Working with Dates

# %%
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# 1. Extract year

# %%
date['date_year'] = date['date'].dt.year

# %%
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year
# 779 2019-07-31        6174        3       4       2019
# 602 2018-07-15        3497       26     234       2018
# 408 2019-05-31        1341       13       8       2019
# 25  2018-09-14        4487       14       1       2018
# 50  2019-06-07        6137        3       3       2019

# %% [markdown]
# 2. Extract Months

# %%
date['date_month_no'] = date['date'].dt.month
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no
# 834 2018-07-27         398       22       8       2018              7
# 304 2018-09-15         438       22      12       2018              9
# 511 2018-12-02        1403       29       3       2018             12
# 210 2018-10-13        3403        1      15       2018             10
# 938 2019-06-21        4587        9      22       2019              6

# %% [markdown]
# 3. Extract Months Name

# %%
date['date_month_name'] = date['date'].dt.month_name()
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no  \
# 827 2019-07-05        2807       26      24       2019              7
# 898 2019-02-20        2945       22       2       2019              2
# 815 2019-12-08        3659       20       4       2019             12
# 881 2019-07-14        2897       26       6       2019              7
# 949 2019-01-01        6533       17       5       2019              1
#
#     date_month_name
# 827            July
# 898        February
# 815        December
# 881            July
# 949         January

# %% [markdown]
# 4. Extract Days

# %%
date['date_day'] = date['date'].dt.day
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no  \
# 941 2018-11-11        4108       13       3       2018             11
# 852 2018-09-04        2706        9       8       2018              9
# 509 2019-07-10        7269       30       2       2019              7
# 577 2018-07-22        2974       26      15       2018              7
# 973 2018-09-08         547        4      19       2018              9
#
#     date_month_name  date_day
# 941        November        11
# 852       September         4
# 509            July        10
# 577            July        22
# 973       September         8

# %%
# Day of week - name

date['date_dow'] = date['date'].dt.day_of_week

# %%
date['date_dow_name']= date['date'].dt.day_name()

# %%
date.sample()
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no  \
# 326 2019-10-29        1675        4       2       2019             10
#
#     date_month_name  date_day  date_dow date_dow_name  date_is_weekend
# 326         October        29         1       Tuesday                0

# %%
# is weekend or not
date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)
